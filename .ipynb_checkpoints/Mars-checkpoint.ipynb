# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

import pandas as pd
from splinter import Browser
from selenium import webdriver
import time

# %% [markdown]
# # Initialize PyMongo to work with MongoDBs
# conn = 'mongodb://localhost:27017'
# client = pymongo.MongoClient(conn)

# %% [markdown]
# # Define database and collection
# db = client._db
# collection = db.articles

# %% [markdown]
# NASA News

# %%
# URL of page to be scraped
url = 'https://mars.nasa.gov/news/'

executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

browser.visit(url)
browser.is_element_present_by_css('li.slide', wait_time=10)

html = browser.html

# %%
# Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')
article = soup.find('div', class_="article_teaser_body").text

article
# Out:
# "Taken with the infrared camera aboard NASA's Odyssey orbiter, they reveal temperature variations on the small moon as it drifts into and out of Mars’ shadow."

# %%
title = soup.find(class_ ="bottom_gradient")
title = title.find('h3').text
title
# Out:
# "Three New Views of Mars' Moon Phobos"

# %%
# URL of page to be scraped
url = 'https://mars.nasa.gov/news/'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'html')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":418,"agent":""}
#   </script>
#   <script type="text/javascript">
# ...

# %%
# URL of page to be scraped
url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.html, 'html.parser')
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-ad8744e1ddad> in <module>
#       5 response = requests.get(url)
#       6 # Create BeautifulSoup object; parse with 'lxml'
# ----> 7 soup = BeautifulSoup(response.html, 'html.parser')
#       8 print(soup.prettify())
#
# AttributeError: 'Response' object has no attribute 'html'

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='content_title') # 'slide'
print(results)
# Out:
# [<div class="content_title">Mars Now</div>, <div class="content_title"><a href="/news/8687/three-new-views-of-mars-moon-phobos/" target="_self">Three New Views of Mars' Moon Phobos</a></div>, <div class="content_title"><a href="/news/8682/the-extraordinary-sample-gathering-system-of-nasas-perseverance-mars-rover/" target="_self">The Extraordinary Sample-Gathering System of NASA's Perseverance Mars Rover</a></div>, <div class="content_title"><a href="/news/8678/the-detective-aboard-nasas-perseverance-rover/" target="_self">The Detective Aboard NASA's Perseverance Rover</a></div>, <div class="content_title"><a href="/news/8680/maven-maps-electric-currents-around-mars-that-are-fundamental-to-atmospheric-loss/" target="_self">MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss</a></div>, <div class="content_title"><a href="/news/8677/air-deliveries-bring-nasas-perseverance-mars-rover-closer-to-launch/" target="_self">Air Deliveries Bring NASA's Perseverance 
# ...

# %%
# Retrieve the parent divs for all articles
results = soup.find_first('div', class_='content_title')

# loop over results to get article data
for result in results:
    # scrape the article header 
    header = result.find('h1', class_='article-item__headline').text
    
    # scrape the article subheader
    subheader = result.find('h2', class_='article-item__subheader').text
    
    # scrape the datetime
    datetime = result.find('span', class_='article-item__date')['data-date'] 
    
    # get only the date from the datetime
    date = datetime.split('T')[0]
    
    # print article data
    print('-----------------')
    print(header)
    print(subheader)
    print(date)

#     # Dictionary to be inserted into MongoDB
#     post = {
#         'header': header,
#         'subheader': subheader,
#         'date': date,
#     }

#     # Insert dictionary into MongoDB as a document
#     collection.insert_one(post)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-85e2b4a7e2c2> in <module>
#       1 # Retrieve the parent divs for all articles
# ----> 2 results = soup.find_first('div', class_='content_title')
#       3
#       4 # loop over results to get article data
#       5 for result in results:
#
# TypeError: 'NoneType' object is not callable

# %% [markdown]
# JPL Mars Space Image

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(url)

# %%
#Scrape Hemisphere Name
 # HTML object
html = browser.html

# Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'lxml')

footer = soup.find('footer') #, 'a', class_='button fancybox')
# print(soup)
print(footer)
string_footer = str(footer)
string_footer= string_footer.split('data-fancybox-href="')[1].split('" data-link')[0]
string_footer
featured_image_url = 'https://www.jpl.nasa.gov' + string_footer
#https://www.jpl.nasa.gov/spaceimages/images/mediumsize/PIA18811_ip.jpg
featured_image_url
# Out:
# <footer>
# <a class="button fancybox" data-description="Hurricane Dorian off the coast of Florida, as seen by the small satellite TEMPEST-D at 2 a.m. EDT on Sep. 3, 2019 (11 p.m PDT on Sept. 2, 2019). The layers in the animation reveal slices of the hurricane from four depths." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/mediumsize/PIA23431_ip.jpg" data-link="/spaceimages/details.php?id=PIA23431" data-title="TEMPEST-D CubeSat Sees Hurricane Dorian in 3D" id="full_image">
# 					FULL IMAGE
# 				  </a>
# </footer>
# 'https://www.jpl.nasa.gov/spaceimages/images/mediumsize/PIA23431_ip.jpg'

# %% [markdown]
# Mars Weather Twitter

# %%
# URL of page to be scraped
url = 'https://twitter.com/marswxreport?lang=en'
driver = webdriver.Chrome()
response = driver.get(url)
#lem = driver.find_element_by_name("div")

#time.sleep(2)

#soup = BeautifulSoup(response.content, 'html.parser')

assert "No results found." not in driver.page_source
soup = BeautifulSoup(response, 'hml')
print(soup)

#pint(elem)
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-166-6089e6921644> in <module>
#      10
#      11 assert "No results found." not in driver.page_source
# ---> 12 soup = BeautifulSoup(response, 'hml')
#      13 print(soup)
#      14
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     226                     "Couldn't find a tree builder with the features you "
#     227                     "requested: %s. Do you need to install a parser library?"
# --> 228                     % ",".join(features))
#     229
#     230         # At this point either we have a TreeBuilder instance in
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: hml. Do you need to install a parser library?

# %%
# URL of page to be scraped
url = 'https://twitter.com/marswxreport?lang=en'

# InSight sol 545 (2020-06-08) low -92.5ºC (-134.5ºF) high -4.9ºC (23.1ºF)
#winds from the SW at 5.4 m/s (12.1 mph) gusting to 20.3 m/s (45.4 mph)
#pressure at 7.40 hPa
# Retrieve page with the requests module
response = requests.get(url)
time.sleep(1)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
# <link href="//abs.twimg.com" rel="preconnect"/>
# <link href="//api.twitter.com" rel="preconnect"/>
# <link href="//pbs.twimg.com" rel="preconnect"/>
# <link href="//t.co" rel="preconnect"/>
# <link href="//video.twimg.com" rel="preconnect"/>
# <link href="//abs.twimg.com" rel="dns-prefetch"/>
# <link href="//api.twitter.com" rel="dns-prefetch"/>
# <link href="//pbs.twimg.com" rel="dns-prefetch"/>
# <link href="//t.co" rel="dns-prefetch"/>
# <link href="//video.twimg.com" rel="dns-prefetch"/>
# <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/web/polyfills.aa560c44.js" nonce="N2Q4NzYyZDgtOTI1My00YzAxLTljYjEtNWE4YTZiNTM1OTAz" rel="preload"/>
# ...

# %%
# Retrieve the parent divs for all articles
mars_weather_results = soup.find('p').text
print(mars_weather_results)
# Out:
# We've detected that JavaScript is disabled in your browser. Would you like to proceed to legacy Twitter?

# %%
# Retrieve the parent divs for all articles
mars_weather_results = soup.find('p', class_="TweetTextSize TweetTextSize--normal js-tweet-text tweet-text").text
print(mars_weather_results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-478bb974173d> in <module>
#       1 # Retrieve the parent divs for all articles
# ----> 2 mars_weather_results = soup.find('p', class_="TweetTextSize TweetTextSize--normal js-tweet-text tweet-text").text
#       3 print(mars_weather_results)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# Mars Facts

# %%
url = "https://space-facts.com/mars/"

# %%
tables = pd.read_html(url, index_col = 0) #, header = None
tables
# Out:
# [                                                  1
#  0
#  Equatorial Diameter:                       6,792 km
#  Polar Diameter:                            6,752 km
#  Mass:                 6.39 × 10^23 kg (0.11 Earths)
#  Moons:                          2 (Phobos & Deimos)
#  Orbit Distance:            227,943,824 km (1.38 AU)
#  Orbit Period:                  687 days (1.9 years)
#  Surface Temperature:                   -87 to -5 °C
#  First Record:                     2nd millennium BC
#  Recorded By:                   Egyptian astronomers,
#                                      Mars            Earth
#  Mars - Earth Comparison
#  Diameter:                       6,779 km        12,742 km
#  Mass:                    6.39 × 10^23 kg  5.97 × 10^24 kg
#  Moons:                                 2                1
#  Distance from Sun:        227,943,824 km   149,598,262 km
#  Length of Year:           687 Earth days      365.24 days
# ...

# %%
mars_facts_df = tables[0]
mars_facts_df
# Out:
#                                                   1
# 0
# Equatorial Diameter:                       6,792 km
# Polar Diameter:                            6,752 km
# Mass:                 6.39 × 10^23 kg (0.11 Earths)
# Moons:                          2 (Phobos & Deimos)
# Orbit Distance:            227,943,824 km (1.38 AU)
# Orbit Period:                  687 days (1.9 years)
# Surface Temperature:                   -87 to -5 °C
# First Record:                     2nd millennium BC
# Recorded By:                   Egyptian astronomers

# %%
html_table = mars_facts_df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>0</th>\n      <th>1</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Equatorial Diameter:</td>\n      <td>6,792 km</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Polar Diameter:</td>\n      <td>6,752 km</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Mass:</td>\n      <td>6.39 × 10^23 kg (0.11 Earths)</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Moons:</td>\n      <td>2 (Phobos &amp; Deimos)</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Orbit Distance:</td>\n      <td>227,943,824 km (1.38 AU)</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Orbit Period:</td>\n      <td>687 days (1.9 years)</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Surface Temperature:</td>\n      <td>-87 to -5 °C</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>First Record:</td>\n      <td>2nd millennium BC</td>\n   
# ...

# %% [markdown]
# Mars Hemispheres

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
browser.visit(url)

# %%
#Scrape Hemisphere Name
 # HTML object
html = browser.html
# Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')
# Retrieve all elements that contain hemisphere information
# hemispheres = soup.find_all('section', id="results-accordian")
hemispheres = soup.find_all('h3')
hemi_list = []
link_list = []

hemispheres

# hemi = hemispheres.find_all('h3')

for h in hemispheres:
    hemi_text = h.text.strip('Enhanced')
    hemi_list.append(hemi_text)
    #Click on Hemisphere Link
    try:
            browser.click_link_by_partial_text(hemi_text)
    except:
            print("Scraping Complete")
    #find image link
    link = browser.find_link_by_text('Original').first['href']
    link_list.append(link)
    #Go Back a Page
    browser.visit(url)
    #print(h)

print(hemi_list)
print(link_list)
# Out:
# []
# []

# %%
#Hard coding values scraped earlier when the site was working
hemi_list = ['Cerberus Hemisphere ', 'Schiaparelli Hemisphere ', 'Syrtis Major Hemisphere ', 'Valles Marineris Hemisphere ']
link_list = ['https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif', 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif', 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif', 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif']

# %%
#Hard coding values scraped earlier when the site was working
hemi_list = ['Cerberus Hemisphere ', 'Schiaparelli Hemisphere ', 'Syrtis Major Hemisphere ', 'Valles Marineris Hemisphere ']
link_list = ['https://astrogeology.usgs.gov/cache/images/f5e372a36edfa389625da6d0cc25d905_cerberus_enhanced.tif_full.jpg', 'https://astrogeology.usgs.gov/cache/images/3778f7b43bbbc89d6e3cfabb3613ba93_schiaparelli_enhanced.tif_full.jpg', 'https://astrogeology.usgs.gov/cache/images/555e6403a6ddd7ba16ddb0e471cadcf7_syrtis_major_enhanced.tif_full.jpg', 'https://astrogeology.usgs.gov/cache/images/b3c7c6c9138f57b4756be9b9c43e3a48_valles_marineris_enhanced.tif_full.jpg']

# %%
hemi_dictionary = dict(zip(hemi_list, link_list))
hemi_dictionary
# Out:
# {'Cerberus Hemisphere ': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif',
#  'Schiaparelli Hemisphere ': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif',
#  'Syrtis Major Hemisphere ': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif',
#  'Valles Marineris Hemisphere ': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif'}

# %%
list(hemi_dictionary.keys())[0]
# Out:
# ['Cerberus Hemisphere ',
#  'Schiaparelli Hemisphere ',
#  'Syrtis Major Hemisphere ',
#  'Valles Marineris Hemisphere ']

# %%
# Iterate through all pages
for x in range():
    # HTML object
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    # Retrieve all elements that contain book information
    articles = soup.find_all('article', class_='product_pod')

    # Iterate through each book
    for article in articles:
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
        h3 = article.find('h3')
        link = h3.find('a')
        href = link['href']
        title = link['title']
        print('-----------')
        print(title)
        print('http://books.toscrape.com/' + href)

    # Click the 'Next' button on each page
    try:
        browser.click_link_by_partial_text('next')
          
    except:
        print("Scraping Complete")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-904325d8c0c9> in <module>
#       1 # Iterate through all pages
# ----> 2 for x in range():
#       3     # HTML object
#       4     html = browser.html
#       5     # Parse HTML with Beautiful Soup
#
# TypeError: range expected 1 arguments, got 0

# %% [markdown]
# Store Scraped Data into Dictionary

# %%
mars_dict = {"article_title": title, "article_excerpt": article, "feature_image": featured_image_url, "fact_table": html_table, "hemisphere_pictures": hemi_dictionary}
mars_dict
# Out:
# {'article_title': "Three New Views of Mars' Moon Phobos",
#  'article_excerpt': "Taken with the infrared camera aboard NASA's Odyssey orbiter, they reveal temperature variations on the small moon as it drifts into and out of Mars’ shadow.",
#  'feature_image': 'https://www.jpl.nasa.gov/spaceimages/images/mediumsize/PIA23431_ip.jpg',
# ...
